# %%
#importing libraries 
import pandas as pd  
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# load data set
df_train =pd.read_csv('candy_train.csv')

# %%
print ("Total number of rows in dataset = {}".format(df_train.shape[0]))
print ("Total number of columns in dataset = {}".format(df_train.shape[1]))
# Out:
# Total number of rows in dataset = 68
# Total number of columns in dataset = 13

# %%
df_train.head()
# Out:
#              competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0               Sugar Daddy          0       0        1               0
# 1  Milky Way Simply Caramel          1       0        1               0
# 2                      Dots          0       1        0               0
# 3            ReeseÕs pieces          1       0        0               1
# 4         Skittles original          0       1        0               0
#
#    nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0       0                 0     0    0         0         0.418         0.325
# 1       0                 0     0    1         0         0.965         0.860
# 2       0                 0     0    0         1         0.732         0.511
# 3       0                 0     0    0         1         0.406         0.651
# 4       0                 0     0    0         1         0.941         0.220
#
#    winpercent
# 0   32.230995
# 1   64.353340
# 2   42.272076
# ...

# %%
df_train.shape
# Out:
# (68, 13)

# %%
df_train.duplicated(keep='last')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# Length: 68, dtype: bool

# %%
df_train.sugarpercent.sort_values(ascending=False)
# Out:
# 61    0.988
# 1     0.965
# 4     0.941
# 51    0.941
# 21    0.906
#       ...
# 44    0.069
# 12    0.046
# 23    0.034
# 27    0.011
# 36    0.011
# Name: sugarpercent, Length: 68, dtype: float64

# %%
df_train.pricepercent.sort_values(ascending=True) #0.976
# Out:
# 62    0.034
# 49    0.058
# 29    0.069
# 57    0.081
# 26    0.093
#       ...
# 10    0.918
# 66    0.918
# 20    0.965
# 5     0.976
# 67    0.976
# Name: pricepercent, Length: 68, dtype: float64

# %%
df_train.corr()
# Out:
#                   chocolate    fruity   caramel  peanutyalmondy    nougat  \
# chocolate          1.000000 -0.813296  0.305876        0.380964  0.272921
# fruity            -0.813296  1.000000 -0.356657       -0.431976 -0.300991
# caramel            0.305876 -0.356657  1.000000        0.048951  0.327576
# peanutyalmondy     0.380964 -0.431976  0.048951        1.000000  0.204509
# nougat             0.272921 -0.300991  0.327576        0.204509  1.000000
# crispedricewafer   0.370087 -0.300991  0.204509       -0.041626 -0.114754
# hard              -0.380072  0.300071 -0.096277       -0.201872 -0.140660
# bar                0.640401 -0.573539  0.342791        0.260714  0.524795
# pluribus          -0.298004  0.381707 -0.322421       -0.172765 -0.328933
# sugarpercent       0.136636 -0.010158  0.207009        0.079652  0.146202
# pricepercent       0.520435 -0.426737  0.214046        0.294288  0.140747
# winpercent         0.645048 -0.427243  0.253867        0.351217  0.196895
#
# ...

# %%
# Visualize a heatmap for our features correlation values
plt.figure(figsize = (30, 15))

# Generate correlation matrix heat map
matrix = np.triu(df_train.corr())
sns.heatmap(df_train.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap='coolwarm', mask=matrix)
# Out:
# <AxesSubplot:>

# %%
# Visualizing with each independent variable
plt.scatter(df_train['chocolate'], df_train['winpercent'], color = 'red')
#plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('chocolate vs winpercent')
plt.xlabel('chocolate')
plt.ylabel('winpercent')
plt.show()

# %%
# Visualizing with each independent variable
plt.scatter(df_train['pricepercent'], df_train['winpercent'], color = 'red')
#plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('pricepercent vs winpercent')
plt.xlabel('pricepercent')
plt.ylabel('winpercent')
plt.show()

# %%
#fruity
# Visualizing with each independent variable
plt.scatter(df_train['fruity'], df_train['winpercent'], color = 'red')
#plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('fruity vs winpercent')
plt.xlabel('fruity')
plt.ylabel('winpercent')
plt.show()

# %%
sns.pairplot(df_train)

# %%
df_train.columns
# Out:
# Index(['competitorname', 'chocolate', 'fruity', 'caramel', 'peanutyalmondy',
#        'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent',
#        'pricepercent', 'winpercent'],
#       dtype='object')

# %%
df_train.fruity.value_counts()
# Out:
# 0    38
# 1    30
# Name: fruity, dtype: int64

# %%
df_train.isnull().sum()
# Out:
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
df_train.head()
# Out:
#              competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0               Sugar Daddy          0       0        1               0
# 1  Milky Way Simply Caramel          1       0        1               0
# 2                      Dots          0       1        0               0
# 3            ReeseÕs pieces          1       0        0               1
# 4         Skittles original          0       1        0               0
#
#    nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0       0                 0     0    0         0         0.418         0.325
# 1       0                 0     0    1         0         0.965         0.860
# 2       0                 0     0    0         1         0.732         0.511
# 3       0                 0     0    0         1         0.406         0.651
# 4       0                 0     0    0         1         0.941         0.220
#
#    winpercent
# 0   32.230995
# 1   64.353340
# 2   42.272076
# ...

# %%
X = df_train.drop(columns=['competitorname','winpercent'])
y = df_train['winpercent']

# %%
#X['sugarpercent']=round(X['sugarpercent']*100).astype(int)
#X['pricepercent']=round(X['pricepercent']*100).astype(int)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chocolate         68 non-null     int64
#  1   fruity            68 non-null     int64
#  2   caramel           68 non-null     int64
#  3   peanutyalmondy    68 non-null     int64
#  4   nougat            68 non-null     int64
#  5   crispedricewafer  68 non-null     int64
#  6   hard              68 non-null     int64
#  7   bar               68 non-null     int64
#  8   pluribus          68 non-null     int64
#  9   sugarpercent      68 non-null     float64
#  10  pricepercent      68 non-null     float64
# dtypes: float64(2), int64(9)
# memory usage: 6.0 KB

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error

def train_model(model, X,y):
    # train-test split 
    X_train, X_test, y_train, y_test = train_test_split (X, y, random_state=42, test_size=0.2)
    model.fit(X_train,y_train)
    
    # predict the results
    pred=model.predict(X_test)
    
    # cross validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    
    print("Results")
    print("MSE: ", np.sqrt(mean_squared_error(y_test,pred)))
    print("CV Score:",np.sqrt(cv_score))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(normalize=True)
train_model(model,X,y)
coef = pd.Series(model.coef_,X.columns).sort_values()
coef.plot(kind='bar', title='Model Coefficients')
# Out:
# Results
# MSE:  13.343482009493691
# CV Score: 12.703509595923009
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train_model(model, X, y)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results
# MSE:  16.437245484569694
# CV Score: 15.997869201541315
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_jobs=-1)
train_model(model, X, y)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results
# MSE:  11.944227162430513
# CV Score: 12.423492582561678
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
# load data set
df_test =pd.read_csv('candy_test.csv')
df_test1 =pd.read_csv('candy_test.csv')

# %%
df_test.shape
# Out:
# (17, 11)

# %%
df_test.head()
# Out:
#       competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0           Chiclets          0       1        0               0       0
# 1           Warheads          0       1        0               0       0
# 2  Haribo Happy Cola          0       0        0               0       0
# 3             Mounds          1       0        0               0       0
# 4              Nerds          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent
# 0                 0     0    0         1         0.046         0.325
# 1                 0     1    0         0         0.093         0.116
# 2                 0     0    0         1         0.465         0.465
# 3                 0     0    1         0         0.313         0.860
# 4                 0     1    0         1         0.848         0.325

# %%
df_test = df_test.drop(columns=['competitorname'])

# %%
pred_test=model.predict(df_test)

# %%
pred_test
# Out:
# array([45.56092528, 36.41608545, 36.42043674, 52.61754696, 39.03551347,
#        34.09766796, 42.97534181, 47.6115111 , 58.66996788, 57.2205074 ,
#        38.12446956, 39.07623531, 47.56627682, 59.36121416, 64.48364012,
#        54.81614851, 36.16859269])

# %%
submission = pd.DataFrame()
submission['competitorname'] = df_test1['competitorname']
submission['winpercent'] = pred_test
submission.to_csv('submission.csv', index=False)

# %%
submission
# Out:
#                competitorname  winpercent
# 0                    Chiclets   45.560925
# 1                    Warheads   36.416085
# 2           Haribo Happy Cola   36.420437
# 3                      Mounds   52.617547
# 4                       Nerds   39.035513
# 5                Pixie Sticks   34.097668
# 6                Sugar Babies   42.975342
# 7           Haribo Sour Bears   47.611511
# 8                       M&MÕs   58.669968
# 9        Tootsie Roll Juniors   57.220507
# 10                 Candy Corn   38.124470
# 11                   Dum Dums   39.076235
# 12                  Red vines   47.566277
# 13                Tootsie Pop   59.361214
# 14  ReeseÕs Peanut Butter cup   64.483640
# 15       Tootsie Roll Midgies   54.816149
# 16             Smarties candy   36.168593

# %% [markdown]
# ***** Completed ****
